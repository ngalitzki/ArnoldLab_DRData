# %%
import subprocess as sp
import os, time, sys
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

path = '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170131-04b/'
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-179-1e65eb4e1e85> in <module>()
#       4 import matplotlib.pyplot as plt
#       5
# ----> 6 get_ipython().magic(u'matplotlib inline')
#       7
#       8 path = '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170131-04b/'
#
# /home/polarbear/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#
# /home/polarbear/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#
# <decorator-gen-106> in matplotlib(self, line)
#
# /home/polarbear/anaconda2/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#
# /home/polarbear/anaconda2/lib/python2.7/site-packages/IPython/core/magics/pylab.pyc in matplotlib(self, line)
#
# /home/polarbear/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in enable_matplotlib(self, gui)
#
# /home/polarbear/anaconda2/lib/python2.7/site-packages/IPython/core/pylabtools.pyc in activate_matplotlib(backend)
#
# /home/polarbear/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in switch_backend(newbackend)
#
# /home/polarbear/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in use(arg, warn, force)
#
# ImportError: No module named backends

# %%
fileNames = os.listdir(path)
files = [path + s for s in fileNames]
files = sorted(files, key = os.path.getctime)
files
# Out:
# ['/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-105057.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-105057RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-105711RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-105711.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-105855.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-105855RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-105900.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-105900RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-111026RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-111026.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-111459.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-111459RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-112031RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-112031.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-112039RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-112039.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-112731RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-112731.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-113917.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-113917RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-114837RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-114837.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-120930.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-120930RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-120936.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-120936RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-123825RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-123825.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-123829.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-123829RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-125005.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-125005RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-125657.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-125657RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-125716.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-125716RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170216-163142_MASTER.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-130639RAW.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-130639.txt',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/.~lock.20170212-130639RAW.txt#',
#  '/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/.~lock.20170212-130639.txt#']

# %%
data = np.array([])
for f in files:
    if f[-4:] == '.txt' and f[-7:] != 'RAW.txt' and f[-10:] != 'MASTER.txt':
        print 'loading from: ', f
        newData = np.loadtxt(f, skiprows = 3, delimiter = ',')
        print 'data shape: ', np.shape(newData)
        if len(newData) != 0:
            if len(data) == 0:
                data = newData
            else:
                data = np.vstack((data, newData))
# Out:
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-105057.txt
# data shape:  (7, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-105711.txt
# data shape:  (0,)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-105855.txt
# data shape:  (0,)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-105900.txt
# data shape:  (7, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-111026.txt
# data shape:  (3, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-111459.txt
# data shape:  (6, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-112031.txt
# data shape:  (0,)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-112039.txt
# data shape:  (5, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-112731.txt
# data shape:  (7, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-113917.txt
# data shape:  (7, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-114837.txt
# data shape:  (4, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-120930.txt
# data shape:  (0,)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-120936.txt
# data shape:  (8, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-123825.txt
# data shape:  (0,)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-123829.txt
# data shape:  (13, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-125005.txt
# data shape:  (4, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-125657.txt
# data shape:  (0,)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-125716.txt
# data shape:  (9, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-130639.txt
# data shape:  (19551, 28)

# %%
plt.figure(figsize = (12,8))
for i in range(1, np.shape(data)[1], 1):
    if i != 6 or i != 7 or i != 8:
        plt.plot(data[:, 0], data[:, i])
    plt.ylim((0, 350))

# %%
rawdata = np.array([])
for f in files:
    if f[-7:] == 'RAW.txt':
        print 'loading from: ', f
        newData = np.loadtxt(f, skiprows = 4, delimiter = ',')
        print 'data shape: ', np.shape(newData)
        if len(newData) != 0:
            if len(rawdata) == 0:
                rawdata = newData
            else:
                rawdata = np.vstack((rawdata, newData))
# Out:
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-105057RAW.txt
# data shape:  (7, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-105711RAW.txt
# data shape:  (0,)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-105855RAW.txt
# data shape:  (0,)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-105900RAW.txt
# data shape:  (7, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-111026RAW.txt
# data shape:  (3, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-111459RAW.txt
# data shape:  (6, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-112031RAW.txt
# data shape:  (0,)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-112039RAW.txt
# data shape:  (5, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-112731RAW.txt
# data shape:  (7, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-113917RAW.txt
# data shape:  (7, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-114837RAW.txt
# data shape:  (4, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-120930RAW.txt
# data shape:  (0,)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-120936RAW.txt
# data shape:  (8, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-123825RAW.txt
# data shape:  (0,)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-123829RAW.txt
# data shape:  (13, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-125005RAW.txt
# data shape:  (4, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-125657RAW.txt
# data shape:  (0,)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-125716RAW.txt
# data shape:  (9, 28)
# loading from:  /home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-130639RAW.txt
# /home/polarbear/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.py:891: UserWarning: loadtxt: Empty input file: "/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-105855RAW.txt"
#   warnings.warn('loadtxt: Empty input file: "%s"' % fname)
# /home/polarbear/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.py:891: UserWarning: loadtxt: Empty input file: "/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-112031RAW.txt"
#   warnings.warn('loadtxt: Empty input file: "%s"' % fname)
# /home/polarbear/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.py:891: UserWarning: loadtxt: Empty input file: "/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-120930RAW.txt"
#   warnings.warn('loadtxt: Empty input file: "%s"' % fname)
# /home/polarbear/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.py:891: UserWarning: loadtxt: Empty input file: "/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-123825RAW.txt"
#   warnings.warn('loadtxt: Empty input file: "%s"' % fname)
# /home/polarbear/anaconda2/lib/python2.7/site-packages/numpy/lib/npyio.py:891: UserWarning: loadtxt: Empty input file: "/home/polarbear/PB2B_Backend/Cooldown_Runs/20170210-05b/Data/20170212-125657RAW.txt"
#   warnings.warn('loadtxt: Empty input file: "%s"' % fname)
# data shape:  (19551, 28)

# %%
with open(files[0], 'r') as f:
    f.seek(66)
    column_headers = f.readline().strip('\n')
    
headerStr = 'Date: ' + time.strftime("%Y/%m/%d") + ', Time: ' + \
            time.strftime("%H:%M:%S") + '\n________________________________\n' + column_headers

masterFileName = time.strftime("%Y%m%d-%H%M%S" + '_MASTER.txt')

np.savetxt(path + masterFileName, data, fmt = '%.16e', delimiter = ',', newline = '\n', header = headerStr, comments = '')

# %%
with open(files[0], 'r') as f:
    f.seek(66)
    column_headers = f.readline().strip('\n')
    
headerStr = 'Date: ' + time.strftime("%Y/%m/%d") + ', Time: ' + \
            time.strftime("%H:%M:%S") + '\nRAW SENSOR UNITS FILE\n________________________________\n' + column_headers

masterFileName = time.strftime("%Y%m%d-%H%M%S" + '_RAW_MASTER.txt')

np.savetxt(path + masterFileName, rawdata, fmt = '%.16e', delimiter = ',', newline = '\n', header = headerStr, comments = '')
